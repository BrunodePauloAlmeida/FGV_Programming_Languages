# %%
import string
texto ='Ferreira Gular disse que seus poemas nascem do espanto. Entendo que seja daquelas epifanias divinas. O que me espanta no entanto é a tragédia, seja ela coletiva ou individual. Nesse momento há a comoção porque temos empatia pelo outro. Choramos porque não estava no programado. Choros se traduzem em poemas. Não precisamos de palavras. Abraços são refrões, beijos são rimas. De um poema nasce a esperança, da tragédia nasce a reflexão e a certeza de foi necessária para que nos tornássemos seres melhores. É preciso levantar e superar cada espanto da vida.'
PUnica={palavra.lower().strip(string.punctuation) for palavra in texto.split()}
Ptodas=[palavra.lower().strip(string.punctuation) for palavra in texto.split()]
Dic={x:Ptodas.count(x) for x in PUnica}
Semaiusculo=[palavra.strip(string.punctuation) for palavra in texto.split()]
Nomes={Semaiusculo[l] for l in range(0,len(Semaiusculo)) if Semaiusculo[l][0]==Semaiusculo[l][0].upper()}
Nomes
# Out:
# {'Abraços',
#  'Choramos',
#  'Choros',
#  'De',
#  'Entendo',
#  'Ferreira',
#  'Gular',
#  'Nesse',
#  'Não',
#  'O',
#  'É'}

# %%
Dic
# Out:
# {'a': 3,
#  'afazeres': 1,
#  'algumas': 1,
#  'alimentado': 1,
#  'amor': 1,
#  'anos': 1,
#  'aperta': 1,
#  'areia': 1,
#  'assim': 1,
#  'atenção': 2,
#  'bom': 1,
#  'canso': 1,
#  'caso': 1,
#  'certa': 2,
#  'certo': 1,
#  'chega': 1,
#  'comida': 1,
#  'como': 1,
#  'completa': 1,
#  'concha': 1,
#  'criado': 1,
#  'cultivado': 1,
#  'cá': 1,
#  'da': 3,
#  'de': 8,
#  'dela': 1,
#  'dentro': 1,
#  'desfrutar': 2,
#  'desfrute': 1,
#  'deve': 1,
#  'dia': 1,
#  'do': 2,
#  'dos': 1,
#  'duradouro': 1,
#  'e': 5,
#  'ela': 4,
#  'encontro': 1,
#  'ensinamentos': 1,
#  'espera': 1,
#  'esse': 1,
#  'está': 2,
#  'eu': 2,
#  'falar': 1,
#  'fascinação': 1,
#  'faço': 1,
#  'felicidade': 1,
#  'feriado': 1,
#  'final': 1,
#  'foram': 1,
#  'formada': 1,
#  'frio': 2,
#  'horas': 1,
#  'imensidão': 1,
#  'imensurável': 1,
#  'imitá-la': 1,
#  'indefinido': 1,
#  'lado': 1,
#  'largo': 1,
#  'linda': 1,
#  'lá': 1,
#  'mais': 1,
#  'maré': 1,
#  'me': 1,
#  'medida': 2,
# ...
